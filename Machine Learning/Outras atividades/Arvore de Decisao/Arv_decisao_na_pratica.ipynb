# %% [markdown]
# Será utilizado o mesmo dataset usado na atividade KNN para verificar os mesmos parametros!

# %%
import pandas as pd

# %%
base = pd.read_excel('/content/funcionarios.xlsx')

# %%
base.head()
# Out:
#    Unnamed: 0  tempo (anos)  departamento_ciencia de dados  \
# 0           0             1                              0
# 1           1             6                              0
# 2           2             3                              1
# 3           3             2                              0
# 4           4             4                              0
#
#    departamento_programacao  departamento_web  nivel_pleno  nivel_senior  \
# 0                         0                 0            0             0
# 1                         0                 1            0             1
# 2                         0                 0            1             0
# 3                         0                 1            0             0
# 4                         1                 0            1             0
#
#   linguagem
# 0         R
# 1      Rubi
# 2    Python
# 3      Java
# 4      Java

# %%
del base['Unnamed: 0']

# %%
base
# Out:
#    tempo (anos)  departamento_ciencia de dados  departamento_programacao  \
# 0             1                              0                         0
# 1             6                              0                         0
# 2             3                              1                         0
# 3             2                              0                         0
# 4             4                              0                         1
# 5             2                              0                         0
# 6             3                              0                         0
# 7             2                              1                         0
# 8            10                              0                         0
# 9             5                              0                         1
#
#    departamento_web  nivel_pleno  nivel_senior linguagem
# 0                 0            0             0         R
# ...

# %%
x = base.iloc[:,:-1]
y = base.iloc[:,-1]

# %%
x
# Out:
#    tempo (anos)  departamento_ciencia de dados  departamento_programacao  \
# 0             1                              0                         0
# 1             6                              0                         0
# 2             3                              1                         0
# 3             2                              0                         0
# 4             4                              0                         1
# 5             2                              0                         0
# 6             3                              0                         0
# 7             2                              1                         0
# 8            10                              0                         0
# 9             5                              0                         1
#
#    departamento_web  nivel_pleno  nivel_senior
# 0                 0            0             0
# 1                 1            0             1
# ...

# %%
y
# Out:
# 0         R
# 1      Rubi
# 2    Python
# 3      Java
# 4      Java
# 5       PHP
# 6    Python
# 7    Python
# 8       PHP
# 9        C#
# Name: linguagem, dtype: object

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
amostra = base.sample()

# %%
amostra
# Out:
#    tempo (anos)  departamento_ciencia de dados  departamento_programacao  \
# 6             3                              0                         0
#
#    departamento_web  nivel_pleno  nivel_senior linguagem
# 6                 0            1             0    Python

# %%
tree.predict(amostra.iloc[:,:-1])
# Out:
# array(['Python'], dtype=object)

# %%
tree.predict([[2,0,0,1,1,0]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['PHP'], dtype=object)

# %%
from sklearn.tree import export_graphviz

# %%
arquivo = open("arvore.dot", "w") # salvar em um novo arquivo para visualizar na ferramenta

# %%
x.columns
# Out:
# Index(['tempo (anos)', 'departamento_ciencia de dados',
#        'departamento_programacao', 'departamento_web', 'nivel_pleno',
#        'nivel_senior'],
#       dtype='object')

# %%
base.linguagem.unique()
# Out:
# array(['R', 'Rubi', 'Python', 'Java', 'PHP', 'C#'], dtype=object)

# %%
export_graphviz(tree, out_file=arquivo,
                feature_names=x.columns,
                class_names=base.linguagem.unique())

# %%
arquivo.close()

# %% [markdown]
# Apos os códigos fazer as ações abaixo:
#
# - abrir o arquivo salvo (arvore.dot) e copiar todos os dados do arquivo.
#
# ![image.png](data:image/png;base64,...)
#
# - abrir o link da ferramenta (http://www.webgraphviz.com/?tab=map) e colar os dados que foram copiados no arquivo dot. Clicar no campo "Generate Graph" para ser gerado a arvóre de decisão com os caminhos gerados usando o Sklearn.
